# %% [markdown]
# # Machine learning

# %% [markdown]
# ## Imports

# %%
import sys
import cufflinks
import pandas as pd
import numpy as np
from tqdm import tqdm
import warnings

warnings.filterwarnings('ignore')

sys.path.append('./..')
cufflinks.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from Corpus.Corpus import get_corpus, filter_binary_pn, filter_corpus_small
from auxiliar.VectorizerHelper import vectorizer, vectorizerIdf, preprocessor
from auxiliar import parameters
from auxiliar.HtmlParser import HtmlParser

# %%
from sklearn.calibration import CalibratedClassifierCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import roc_auc_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import roc_curve
from sklearn.model_selection import KFold
import copy

# %% [markdown]
# ## Config

# %%
polarity_dim = 5
clasificadores=['lr', 'ls', 'mb', 'rf']
idf =  False
target_names=['Neg', 'Pos']
kfolds = 10
base_dir = '2-clases' if polarity_dim == 2 else ('3-clases' if polarity_dim == 3 else '5-clases')
name = 'machine_learning/tweeter/base_line'

# %% [markdown]
# ## Get data

# %%
cine = HtmlParser(200, "http://www.muchocine.net/criticas_ultimas.php", 1)
data_corpus = get_corpus('general-corpus', 'general-corpus', 1, None)

if polarity_dim == 2:
    data_corpus = filter_binary_pn(data_corpus)
    cine = filter_binary_pn(cine.get_corpus())
elif polarity_dim == 3:
    data_corpus = filter_corpus_small(data_corpus)
    cine = filter_corpus_small(cine.get_corpus())
elif polarity_dim == 5:
    cine = cine.get_corpus()
cine = cine[:5000]
used_data = cine
split = used_data.shape[0] * 0.7
data_corpus = None
# Out:
# #Intentando obtener datos del archivo csv...
# ./../Corpus/../data/general-corpus.csv
# #Datos recuperados!

# %% [markdown]
# ## Split data

# %%
used_data.reset_index().groupby('polarity').agg({'index': 'count'}).iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="1ed01490-dc82-4892-ac6a-d61406b5487a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("1ed01490-dc82-4892-ac6a-d61406b5487a")) {
#                     Plotly.newPlot(
#                         '1ed01490-dc82-4892-ac6a-d61406b5487a',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "index", "orientation": "v", "text": "", "type": "bar", "uid": "4291111f-23ea-42c2-a71e-c57ef1347461", "x": [1, 2, 3, 4, 5], "y": [245, 895, 2040, 1345, 475]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('1ed01490-dc82-4892-ac6a-d61406b5487a');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
train_corpus = used_data.loc[:split - 1 , :]
test_corpus = used_data.loc[split:, :]

# %% [markdown]
# ## Initialize ML

# %%
vect = vectorizerIdf if idf else vectorizer
ls = CalibratedClassifierCV(LinearSVC()) if polarity_dim == 2 else OneVsRestClassifier(CalibratedClassifierCV(LinearSVC()))
lr = LogisticRegression(solver='lbfgs') if polarity_dim == 2 else OneVsRestClassifier(LogisticRegression())
mb = MultinomialNB() if polarity_dim == 2 else OneVsRestClassifier(MultinomialNB())
rf = RandomForestClassifier() if polarity_dim == 2 else OneVsRestClassifier(RandomForestClassifier())

# %%
pipeline_ls = Pipeline([
    ('vect', copy.deepcopy(vect)),
    ('ls', ls)
])
pipeline_lr = Pipeline([
    ('vect', copy.deepcopy(vect)),
    ('lr', lr)
])
pipeline_mb = Pipeline([
    ('vect', copy.deepcopy(vect)),
    ('mb', mb)
])
pipeline_rf = Pipeline([
    ('vect', copy.deepcopy(vect)),
    ('rf', rf)
])

# %%
pipelines = {
    'ls': pipeline_ls,
    'lr': pipeline_lr,
    'mb': pipeline_mb,
    'rf': pipeline_rf
}
pipelines_train = {
    'ls': ls,
    'lr': lr,
    'mb': mb,
    'rf': rf
}

# %% [markdown]
# ## Train

# %%
folds = pd.read_pickle('../data/pkls/folds.pkl') # k-folds precargados
folds = folds.values

# %%
x_vect = vect.fit_transform(train_corpus.content, train_corpus.polarity).toarray()

# %%
cine_vect = vect.transform(cine.content).toarray()

# %%
vect.vocabulary_
# Out:
# {'El': 6278,
#  'saqueo': 61430,
#  'obras': 52240,
#  'arte': 24731,
#  'tiempos': 64820,
#  'guerra': 43360,
#  'siempre': 62129,
#  'sido': 62124,
#  'tema': 64446,
#  'recurrente': 58752,
#  'historia': 44117,
#  'debido': 33002,
#  'trata': 65713,
#  'herramienta': 43928,
#  'fundamental': 42380,
#  'ser': 61919,
#  'humano': 44427,
#  'ya': 67817,
#  'define': 33290,
#  'sociedad': 62708,
#  'través': 65781,
#  'sus': 63909,
#  'corrientes': 31853,
#  'tendencias': 64528,
#  'Con': 4321,
#  'hecho': 43822,
#  'pretende': 56379,
#  'nación': 51508,
#  'invasora': 46885,
#  'algún': 22839,
#  'modo': 50716,
#  'adueñarse': 22043,
#  'raíces': 58102,
#  'identidad': 44595,
#  'siendo': 62132,
#  'acto': 21579,
#  'represivo': 59722,
#  'aparte': 23931,
#  'delictivo': 33512,
#  'evidentemente': 40289,
#  'Sucedió': 18153,
#  'ejércitos': 37102,
#  'Asiria': 1652,
#  'Egipto': 6240,
#  'Grecia': 8240,
#  'Roma': 16278,
#  'pasando': 53698,
#  'campañas': 27737,
#  'napoleónicas': 51529,
#  'colonización': 29711,
#  'británica': 27015,
#  'supuesto': 63858,
#  'regímenes': 59133,
#  'totalitarios': 65258,
#  'Hitler': 9062,
#  'Mussolini': 13192,
#  'segunda': 61664,
#  'mundial': 51282,
#  'largo': 47794,
#  'cine': 29110,
#  'películas': 54161,
#  'tratado': 65718,
#  'más': 51412,
#  'representativa': 59714,
#  'clásico': 29367,
#  'John': 10146,
#  'Frankenheimer': 7460,
#  'Tren': 19117,
#  'incluso': 45304,
#  'candidata': 27799,
#  'premio': 56110,
#  'Óscar': 68026,
#  '1966': 173,
#  'mejor': 49964,
#  'guion': 43394,
#  'ofrece': 52526,
#  'mejores': 49987,
#  'interpretaciones': 46631,
#  'Burt': 3042,
#  'Lancaster': 10928,
#  'George': 7880,
#  'Clooney': 4129,
#  'célebre': 32793,
#  'actor': 21580,
#  'también': 64160,
#  'ejerce': 37082,
#  'director': 35829,
#  'productor': 56679,
#  'guionista': 43397,
#  'querido': 57727,
#  'tratar': 65725,
#  'expolio': 40755,
#  'conflictos': 30669,
#  'bélicos': 27284,
#  'su': 63225,
#  'quinta': 57789,
#  'película': 54156,
#  'detrás': 35414,
#  'cámaras': 32772,
#  'Para': 14346,
#  'inspirado': 46292,
#  'libro': 48168,
#  'The': 18739,
#  'Monuments': 12983,
#  'Men': 12514,
#  'Allied': 1022,
#  'Heroes': 8933,
#  'Nazi': 13433,
#  'Thieves': 18761,
#  'and': 23457,
#  'the': 64780,
#  'Greatest': 8238,
#  'Treasure': 19105,
#  'Hunt': 9282,
#  'in': 45160,
#  'History': 9048,
#  'escrito': 39318,
#  'Robert': 16199,
#  'Edsel': 6205,
#  'basado': 26249,
#  'vez': 67075,
#  'hechos': 43823,
#  'reales': 58144,
#  'reunido': 60305,
#  'elenco': 37165,
#  'actoral': 21581,
#  'lujo': 48817,
#  'repleto': 59652,
#  'amiguetes': 23288,
#  'llevarlo': 48538,
#  'cabo': 27352,
#  'podemos': 55378,
#  'encontrar': 37982,
#  'Goodman': 8127,
#  'Bill': 2481,
#  'Murray': 13175,
#  'Matt': 12245,
#  'Damon': 5095,
#  'Bob': 2598,
#  'Balaban': 2040,
#  'Jean': 10018,
#  'Dujardin': 5970,
#  'Cate': 3648,
#  'Blanchet': 2546,
#  'contarnos': 31223,
#  'envuelve': 38917,
#  'clave': 29322,
#  'comedia': 29805,
#  'personalmente': 54659,
#  'recordado': 58598,
#  'Los': 11475,
#  'violentos': 67287,
#  'Kelly': 10495,
#  'Brian': 2853,
#  'Hutton': 9308,
#  'salvando': 61327,
#  'distancias': 36186,
#  'ahí': 22546,
#  'donde': 36523,
#  'flojea': 41801,
#  'fallidos': 41114,
#  'gags': 42534,
#  'cómicos': 32824,
#  'restan': 60056,
#  'dramatismo': 36603,
#  'héroes': 44533,
#  'anónimos': 23826,
#  'dado': 32854,
#  'vida': 67137,
#  'preservar': 56275,
#  'cultura': 32614,
#  'Además': 719,
#  'punto': 57439,
#  'duración': 36736,
#  'algo': 22832,
#  'excesiva': 40416,
#  'dos': 36551,
#  'horas': 44280,
#  'sumado': 63586,
#  'falta': 41139,
#  'tensión': 64576,
#  'deja': 33375,
#  'sensación': 61786,
#  'señor': 62063,
#  'pesar': 54763,
#  'buenas': 27112,
#  'intenciones': 46452,
#  'perdido': 54355,
#  'oportunidad': 52768,
#  'ideal': 44577,
#  'hacer': 43618,
#  'grande': 43121,
#  'quedándose': 57655,
#  'medias': 49876,
#  'Algunas': 982,
#  'veces': 66713,
#  'da': 32847,
#  'impresión': 45087,
#  'guión': 43422,
#  'va': 66488,
#  'dando': 32872,
#  'palos': 53274,
#  'ciego': 29048,
#  'perdiendo': 54357,
#  'hilo': 44006,
#  'conductor': 30548,
#  'principal': 56510,
#  'diluyéndose': 35764,
#  'subtramas': 63353,
#  'llegar': 48463,
#  'profundizar': 56742,
#  'ninguna': 51857,
#  'adolece': 21923,
#  'figura': 41527,
#  'villano': 67238,
#  'podría': 55412,
#  'considerar': 30997,
#  'tal': 64124,
#  'interpretado': 46636,
#  'alemán': 22805,
#  'Justus': 10314,
#  'von': 67615,
#  'Dohnányi': 5782,
#  'Viktor': 19776,
#  'Stahl': 17959,
#  'está': 40164,
#  'desdibujado': 34354,
#  'peso': 54790,
#  'Huelga': 9244,
#  'decir': 33142,
#  'desperdiciado': 34947,
#  'talento': 64129,
#  'estupendo': 40150,
#  'solamente': 62748,
#  'hay': 43789,
#  'ver': 66904,
#  'impresionante': 45075,
#  'interpreta': 46626,
#  'muy': 51377,
#  'recomendable': 58477,
#  'culto': 32612,
#  'experimento': 40639,
#  'Oliver': 13915,
#  'Hirschbiegel': 9035,
#  'darse': 32904,
#  'cuenta': 32485,
#  'Aunque': 1790,
#  'favor': 41330,
#  'factura': 41067,
#  'técnica': 66160,
#  'filme': 41600,
#  'parecido': 53502,
#  'brillante': 26965,
#  'ambientación': 23188,
#  'lograda': 48668,
#  'También': 18512,
#  'labor': 47638,
#  'realmente': 58188,
#  'bien': 26533,
#  'destacaría': 35129,
#  'extraña': 40958,
#  'pareja': 53523,
#  'formada': 41952,
#  'En': 6419,
#  'definitiva': 33306,
#  'tener': 64557,
#  'mimbres': 50448,
#  'buen': 27108,
#  'demostrado': 33603,
#  'realizadas': 58164,
#  'anteriormente': 23671,
#  'Buenas': 2987,
#  'noches': 51899,
#  'buena': 27109,
#  'suerte': 63489,
#  'idus': 44652,
#  'marzo': 49637,
#  'no': 51893,
#  'sabido': 61023,
#  'aprovechar': 24266,
#  'potencial': 55812,
#  'tenía': 64597,
#  'manos': 49369,
#  'No': 13599,
#  'obstante': 52308,
#  'entretiene': 38794,
#  'De': 5200,
#  'entrada': 38650,
#  'parte': 53601,
#  'reparto': 59570,
#  'bueno': 27116,
#  'Hugh': 9251,
#  'Hackman': 8573,
#  'cabeza': 27337,
#  'seguido': 61641,
#  'Jake': 9946,
#  'Gyllenhaal': 8446,
#  'Viola': 19822,
#  'Davis': 5190,
#  'Maria': 12066,
#  'Bello': 2315,
#  'Terrence': 18698,
#  'Howard': 9216,
#  'Melissa': 12494,
#  'Leo': 11145,
#  'Paul': 14482,
#  'Dano': 5127,
#  'dirección': 35819,
#  'Denis': 5376,
#  'Villeneuve': 19797,
#  'responsable': 60042,
#  'nominada': 51949,
#  'Oscar': 14040,
#  'Incendies': 9530,
#  'Pero': 14653,
#  'partida': 53634,
#  'Ya': 20413,
#  'Prisioneros': 15179,
#  'trae': 65343,
#  'secuestros': 61580,
#  'infantiles': 45738,
#  'consecuencias': 30921,
#  'conlleva': 30789,
#  'toma': 65039,
#  'tiempo': 64819,
#  'desgranar': 34646,
#  'acontecimientos': 21447,
#  'cociéndolos': 29447,
#  'fuego': 42283,
#  'lento': 47994,
#  'pausa': 53913,
#  'dándonos': 36774,
#  'pistas': 55099,
#  'camino': 27709,
#  'escondidas': 39273,
#  'vista': 67384,
#  'si': 62106,
#  'tratara': 65726,
#  'gran': 43116,
#  'novela': 52057,
#  'negra': 51732,
#  'Mientras': 12670,
#  'viendo': 67181,
#  'vinieron': 67255,
#  'Mystic': 13216,
#  'River': 16178,
#  'Clint': 4120,
#  'Eastwood': 6166,
#  'similitudes': 62252,
#  'comparte': 30010,
#  'Otra': 14071,
#  'vino': 67260,
#  'Zodiac': 20648,
#  'David': 5187,
#  'Fincher': 7258,
#  'Sin': 17562,
#  'lugar': 48807,
#  'dudas': 36678,
#  'thriller': 64796,
#  'nivel': 51877,
#  'Oscuro': 14047,
#  'desgarrador': 34617,
#  'asfixiante': 24935,
#  'Que': 15418,
#  'atrapa': 25364,
#  'suelta': 63478,
#  'final': 41640,
#  'Todo': 18898,
#  'gracias': 43079,
#  'complejo': 30118,
#  'hilvanado': 44010,
#  'medida': 49890,
#  'film': 41578,
#  'avanza': 25731,
#  'van': 66625,
#  'encajando': 37748,
#  'forma': 41947,
#  'precisa': 55933,
#  'piezas': 54937,
#  'rompecabezas': 60776,
#  'plantea': 55215,
#  'cuestiones': 32529,
#  'reza': 60473,
#  'cartel': 28197,
#  'promocional': 56850,
#  'Hasta': 8743,
#  'puede': 57343,
#  'persona': 54645,
#  'hija': 43981,
#  'desaparecida': 33945,
#  'Destaca': 5512,
#  'genial': 42775,
#  'sobresaliendo': 62635,
#  'encima': 37945,
#  'rol': 60748,
#  'padre': 53147,
#  'coraje': 31716,
#  'capaz': 27917,
#  'traspasar': 65682,
#  'límites': 48883,
#  'racional': 57882,
#  'niveles': 51879,
#  'insospechados': 46279,
#  'policía': 55464,
#  'encargado': 37827,
#  'caso': 28259,
#  'sobretodo': 62647,
#  'Personalmente': 14677,
#  'gustaría': 43454,
#  'destacar': 35121,
#  'casi': 28252,
#  'inexistente': 45704,
#  'banda': 26138,
#  'sonora': 62924,
#  'utiliza': 66447,
#  'ciertos': 29085,
#  'momentos': 50804,
#  'trama': 65422,
#  'pitidos': 55112,
#  'característicos': 28012,
#  'automóviles': 25660,
#  'suenan': 63485,
#  'cuando': 32403,
#  'dejas': 33417,
#  'luces': 48758,
#  'encendidas': 37908,
#  'abres': 20875,
#  'puerta': 57353,
#  'cierto': 29084,
#  'integra': 46412,
#  'dentro': 33673,
#  'ambiental': 23193,
#  'plana': 55170,
#  'reina': 59151,
#  'silencio': 62209,
#  'consigue': 31024,
#  'potenciar': 55818,
#  'aun': 25549,
#  'agonía': 22341,
#  'desesperación': 34549,
#  'transmite': 65547,
#  'potente': 55822,
#  'media': 49865,
#  'metraje': 50299,
#  'hace': 43607,
#  'esté': 40176,
#  'engranado': 38308,
#  'maquinaria': 49464,
#  'reloj': 59346,
#  'afirmar': 22198,
#  'notable': 52010,
#  'aunque': 25554,
#  'cuente': 32489,
#  'nada': 51510,
#  'nuevo': 52112,
#  'logra': 48666,
#  'contarlo': 31221,
#  'manera': 49301,
#  'intensa': 46455,
#  'inteligente': 46436,
#  'digno': 35718,
#  'admirar': 21900,
#  'además': 21773,
#  'desasosiego': 34014,
#  'instalada': 46312,
#  'interior': 46573,
#  'terminada': 64634,
#  'Capitan': 3452,
#  'Phillips': 14741,
#  'guarda': 43308,
#  'bastantes': 26281,
#  'estructura': 40102,
#  'narrativa': 51567,
#  'United': 19403,
#  '93': 414,
#  'Greengrass': 8246,
#  'relataba': 59282,
#  'atentados': 25231,
#  '11': 36,
#  'Septiembre': 17198,
#  'centrándose': 28646,
#  'Vuelo': 19936,
#  'Airlines': 865,
#  'llegó': 48492,
#  'destino': 35176,
#  'reacción': 58119,
#  'heroica': 43914,
#  'pasajeros': 53693,
#  'abarca': 20747,
#  'crónica': 32357,
#  'basada': 26247,
#  'propio': 56928,
#  'inspira': 46285,
#  'secuestro': 61579,
#  'buque': 27157,
#  'carguero': 28105,
#  'Maersk': 11823,
#  'Alabama': 883,
#  'cargo': 28101,
#  'piratas': 55053,
#  'somalíes': 62863,
#  'Me': 12424,
#  'gustado': 43438,
#  'mantiene': 49410,
#  'dejándote': 33439,
#  'prácticamente': 57176,
#  'respiración': 60009,
#  'Una': 19378,
#  'destaca': 35108,
#  'interpretación': 46632,
#  'Tom': 18927,
#  'Hanks': 8662,
#  'aventuraría': 25777,
#  'Naufrago': 13408,
#  '2000': 214,
#  'Zemeckis': 20617,
#  'realizaba': 58158,
#  'calibre': 27542,
#  'visceral': 67322,
#  'echa': 36832,
#  'espalda': 39480,
#  'ensalza': 38457,
#  'muchísimo': 51168,
#  'voy': 67635,
#  'desvelar': 35275,
#  'derrocha': 33817,
#  'lleva': 48517,
#  'Lo': 11387,
#  'dicho': 35575,
#  'actuación': 21603,
#  'memorable': 50034,
#  'digna': 35709,
#  'elogios': 37246,
#  'tono': 65102,
#  'impregna': 45046,
#  'falso': 41135,
#  'documental': 36429,
#  'elección': 37125,
#  'plantel': 55238,
#  'actores': 21589,
#  'desconocidos': 34238,
#  'acierto': 21313,
#  'total': 65253,
#  'interpretan': 46639,
#  'dan': 32868,
#  'realismo': 58151,
#  'brutal': 27077,
#  'Por': 15019,
#  'llega': 48453,
#  'ofrecido': 52540,
#  'ligeramente': 48229,
#  'apuras': 24346,
#  'ocasiones': 52360,
#  'puntuales': 57445,
#  'cámara': 32770,
#  'mueve': 51219,
#  'exceso': 40422,
#  'desaprovecha': 33969,
#  'Katherine': 10435,
#  'Keener': 10479,
#  'mujer': 51228,
#  'presencia': 56218,
#  'testimonial': 64735,
#  'nimiedades': 51852,
#  'hacen': 43617,
#  'obra': 52236,
#  'maestra': 48988,
#  'tampoco': 64167,
#  'antes': 23672,
#  'vuelta': 67655,
#  'realiza': 58157,
#  'papelón': 53362,
#  'órdago': 68186,
#  'confirma': 30645,
#  'realizador': 58166,
#  'estadounidense': 39799,
#  'cronistas': 32269,
#  'cinematográficos': 29135,
#  'actualidad': 21610,
#  'junto': 47461,
#  'Bigelow': 2471,
#  'citar': 29210,
#  'Se': 17037,
#  'acabado': 21046,
#  'crisis': 32207,
#  '26': 264,
#  'tasa': 64284,
#  'paro': 53562,
#  'Sueldos': 18168,
#  'ridículos': 60540,
#  'Sanidad': 16844,
#  'educación': 36952,
#  'masacradas': 49642,
#  'mitad': 50612,
#  'riqueza': 60584,
#  'población': 55350,
#  'Qué': 15482,
#  'hijos': 43989,
#  'puta': 57497,
#  'Durante': 6008,
#  'bombardeo': 26784,
#  'puedes': 57345,
#  'escuchar': 39352,
#  'necesario': 51652,
#  'Poder': 14931,
#  'parar': 53453,
#  'poder': 55379,
#  'respirar': 60013,
#  'pensar': 54227,
#  'sentir': 61850,
#  'acostumbrado': 21509,
#  'Guernika': 8353,
#  'miseria': 50572,
#  'miedo': 50379,
#  'dolor': 36459,
#  'impotencia': 45035,
#  'esclavitud': 39223,
#  'muerte': 51204,
#  'Porque': 15023,
#  'vivir': 67465,
#  'sintiéndose': 62380,
#  'miserable': 50569,
#  'miedoso': 50381,
#  'dolorido': 36461,
#  'impotente': 45037,
#  'esclavo': 39230,
#  'muerto': 51206,
#  'merece': 50151,
#  'pena': 54169,
#  'hierve': 43973,
#  'sangre': 61381,
#  'cosas': 31941,
#  'guerrero': 43365,
#  'Si': 17454,
#  'luchas': 48775,
#  'pueden': 57344,
#  'joderte': 47309,
#  'estás': 40171,
#  'jodido': 47314,
#  'Contaba': 4437,
#  'Che': 3829,
#  'Guevara': 8363,
#  'Naciones': 13314,
#  'Unidas': 19397,
#  'tratan': 65723,
#  'masacrarnos': 49648,
#  'liquidar': 48341,
#  'pueblo': 57338,
#  'fuerte': 42292,
#  'sigue': 62184,
#  'día': 36805,
#  'anotándose': 23620,
#  'nuevas': 52108,
#  'victorias': 67132,
#  'Este': 6727,
#  'pequeña': 54278,
#  'victoria': 67126,
#  'Un': 19376,
#  'dinero': 35793,
#  'ganas': 42623,
#  'pelear': 54084,
#  'necesidad': 51654,
#  'aportar': 24106,
#  'dejar': 33394,
#  'estar': 39853,
#  'brazos': 26936,
#  'cruzados': 32323,
#  'gritar': 43233,
#  'masacre': 49650,
#  'terminar': 64643,
#  'hora': 44275,
#  '15': 68,
#  'minutos': 50520,
#  'reflexionar': 58959,
#  'neoliberalismo': 51758,
#  'capitalismo': 27926,
#  'formas': 41971,
#  'lucha': 48759,
#  'contado': 31181,
#  'intervención': 46703,
#  'José': 10197,
#  'Luis': 11565,
#  'Sampedro': 16817,
#  'Juan': 10221,
#  'Manuel': 12000,
#  'Sánchez': 18354,
#  'Gordillo': 8143,
#  'Diego': 5617,
#  'Cañamero': 3690,
#  'Torres': 18998,
#  'Julio': 10265,
#  'Anguita': 1247,
#  'Carlos': 3519,
#  'Bardem': 2123,
#  'Iñaki': 9866,
#  'Gabilondo': 7681,
#  'Teresa': 18680,
#  'Forcades': 7391,
#  'Rosa': 16335,
#  'María': 12171,
#  'Calaf': 3310,
#  'filósofos': 41634,
#  'Bermudo': 2385,
#  'Marina': 12089,
#  'Garcés': 7767,
#  'último': 68198,
#  'participó': 53627,
#  'detalle': 35339,
#  'modesto': 50704,
#  'toque': 65151,
#  'especial': 39516,
#  'empatía': 37513,
#  'magia': 49008,
#  'conexión': 30579,
#  'admiración': 21887,
#  'hombre': 44195,
#  '95': 416,
#  'años': 25978,
#  'luchando': 48769,
#  'cambiar': 27660,
#  'mundo': 51286,
#  'sabios': 61030,
#  'venden': 66809,
#  'mueren': 51199,
#  'botas': 26893,
#  'puestas': 57359,
#  'sistema': 62424,
#  'roto': 60836,
#  'futuro': 42469,
#  'valiente': 66562,
#  'apuesta': 24310,
#  'Su': 18131,
#  'descaro': 34128,
#  'partidista': 53639,
#  'olvido': 52655,
#  'desprecio': 35043,
#  'Capitalismo': 3451,
#  'derecha': 33777,
#  'debe': 32979,
#  'morir': 50997,
#  'olvidarla': 52637,
#  'peor': 54269,
#  'desprecios': 35044,
#  'posiciones': 55741,
#  'neoliberales': 51757,
#  'recalcitrante': 58284,
#  'qué': 57851,
#  'cuentan': 32487,
#  'patrañas': 53870,
#  'días': 36807,
#  'periódicos': 54481,
#  'televisiones': 64425,
#  'medios': 49908,
#  'Lloverán': 11381,
#  'piedras': 54916,
#  'arbitrariedad': 24383,
#  'crítica': 32353,
#  'honestidad': 44247,
#  'halago': 43687,
#  'quizás': 57848,
#  'izquierdas': 47197,
#  'jamás': 47234,
#  'indica': 45566,
#  'sino': 62362,
#  'abre': 20872,
#  'caminos': 27710,
#  'escoger': 39240,
#  'quiere': 57762,
#  'seguir': 61649,
#  'Decía': 5270,
#  'creyendo': 32153,
#  'todavía': 65022,
#  'capaces': 27910,
#  'temblar': 64455,
#  'indignación': 45597,
#  'cada': 27411,
#  'comete': 29897,
#  'injusticia': 46015,
#  'Esperemos': 6685,
#  'haga': 43675,
#  'poquito': 55597,
#  'Es': 6592,
#  'aullar': 25537,
#  'dejamos': 33385,
#  'llevar': 48532,
#  'poderes': 55380,
#  'gobiernan': 42961,
#  'hacemos': 43616,
#  'contrarrestarlos': 31413,
#  'merecemos': 50157,
#  'Imaginad': 9473,
#  'podéis': 55417,
#  'paredes': 53522,
#  'ropa': 60816,
#  'carne': 28144,
#  'Pensad': 14587,
#  'cuantísimas': 32415,
#  'podríais': 55413,
#  'médicos': 51427,
#  'diagnosticarían': 35515,
#  'enfermedades': 38152,
#  'sola': 62746,
#  'mirada': 50528,
#  'espiar': 39659,
#  'descubierto': 34301,
#  'jugar': 47409,
#  'póker': 57578,
#  'ganar': 42615,
#  'requiere': 59818,
#  'responsabilidad': 60039,
#  'literatura': 48376,
#  'enseñado': 38493,
#  'destrucción': 35220,
#  'individuo': 45627,
#  'peli': 54094,
#  'vengo': 66872,
#  'hablar': 43563,
#  'hoy': 44364,
#  'Rayos': 15705,
#  'ojos': 52591,
#  '1963': 170,
#  'científico': 29069,
#  'James': 9956,
#  'Xavier': 20404,
#  'Ray': 15697,
#  'Millard': 12718,
#  'desarrolla': 33990,
#  'gotas': 43028,
#  'destinadas': 35169,
#  'aumentar': 25545,
#  'gama': 42584,
#  'visión': 67373,
#  'humana': 44411,
#  'permite': 54527,
#  'allá': 22924,
#  'visible': 67331,
#  'Convencido': 4488,
#  'pruebas': 57173,
#  'animales': 23568,
#  'suficientes': 63504,
#  'decide': 33109,
#  'probar': 56582,
#  'él': 68092,
#  'descubriendo': 34310,
#  'maravilla': 49478,
#  'científica': 29066,
#  'ayudar': 25880,
#  'salvar': 61328,
#  'vidas': 67138,
#  'Cada': 3282,
#  'usas': 66419,
#  'usarlas': 66412,
#  'desquiciándose': 35102,
#  'matando': 49714,
#  'colegas': 29628,
#  'centro': 28642,
#  'trabaja': 65276,
#  'uso': 66423,
#  'continuado': 31329,
#  'dejará': 33412,
#  'términos': 66169,
#  'humanos': 44430,
#  'sólo': 64055,
#  'texturas': 64767,
#  'cerebro': 28687,
#  'incapaz': 45224,
#  'comprender': 30235,
#  'plenamente': 55314,
#  'Después': 5509,
#  'asesinato': 24912,
#  'pasará': 53720,
#  'fenómeno': 41415,
#  'feria': 41419,
#  'intentando': 46475,
#  'ocultarse': 52404,
#  'Las': 10982,
#  'alteran': 22996,
#  'primero': 56474,
#  'plata': 55275,
#  'negro': 51740,
#  'finalmente': 41658,
#  'negros': 51741,
#  'ocultar': 52401,
#  'apariencia': 23914,
#  'gafas': 42528,
#  'sol': 62745,
#  'discretas': 35921,
#  'intentan': 46474,
#  'envolver': 38903,
#  've': 66703,
#  'oscuridad': 53000,
#  'Como': 4293,
#  'imaginar': 44778,
#  'volviendo': 67589,
#  'obsesivo': 52297,
#  'quedará': 57643,
#  'catacroquer': 28321,
#  'llevará': 48546,
#  'personaje': 54646,
#  'dramático': 36617,
#  'Técnicamente': 19290,
#  'avanzada': 25734,
#  'primeras': 56470,
#  'realizaciones': 58161,
#  'Roger': 16261,
#  'Corman': 4552,
#  'Ojo': 13885,
#  'presupuesto': 56363,
#  '250': 262,
#  '000': 1,
#  'dólares': 36820,
#  'millonada': 50434,
#  'éste': 68117,
#  'descubre': 34306,
#  'mala': 49067,
#  'buenísimo': 27126,
#  'mano': 49368,
#  'Dillon': 5653,
#  'Rusell': 16468,
#  'atreve': 25416,
#  'había': 43603,
#  'podido': 55391,
#  'primera': 56467,
#  'carrera': 28171,
#  'personajes': 54647,
#  'atreven': 25418,
#  'mirar': 50539,
#  'justificación': 47496,
#  'temática': 64514,
#  'atreverá': 25424,
#  'planos': 55201,
#  'secuencia': 61564,
#  'arriesgado': 24654,
#  'diferente': 35651,
#  'anteriores': 23669,
#  'cuadraba': 32362,
#  'esquema': 39740,
#  'extremadamente': 40976,
#  'subjetiva': 63286,
#  'Tratando': 19093,
#  'mostrar': 51050,
#  'espectador': 39547,
#  'loco': 48641,
#  'volar': 67531,
#  'imaginación': 44770,
#  'mostrando': 51048,
#  'hiciera': 43953,
#  'supiera': 63796,
#  'pánico': 57546,
#  'quedara': 57632,
#  'mal': 49066,
#  'explica': 40660,
#  'autobiografía': 25594,
#  'cagueta': 27465,
#  'Cuando': 4820,
#  'Dr': 5880,
#  'solo': 62808,
#  'luz': 48848,
#  'color': 29719,
#  'imágenes': 45158,
#  'vanguardistas': 66634,
#  'recuerdan': 58710,
#  'Man': 11934,
#  'principios': 56518,
#  'siglo': 62157,
#  'imaginativas': 44795,
#  'artista': 24770,
#  'surrealista': 63901,
#  'claramente': 29262,
#  'llenas': 48507,
#  'fantástico': 41226,
#  'Milland': 12716,
#  'hizo': 44154,
#  'pleno': 55318,
#  'declive': 33179,
#  'cinematográfico': 29134,
#  'Dias': 5587,
#  'huella': 44384,
#  'Billy': 2484,
#  'Wilder': 20229,
#  '1945': 150,
#  'gano': 42634,
#  'protagonista': 57006,
#  'comenzó': 29870,
#  'sufrir': 63528,
#  'lentísimo': 47996,
#  'protagonizará': 57025,
#  'joyitas': 47359,
#  'Crimen': 4714,
#  'Perfecto': 14643,
#  'Alfred': 973,
#  'Hitchcock': 9055,
#  '1954': 159,
#  'cree': 32107,
#  'empezó': 37566,
#  'ir': 47032,
#  'dio': 35802,
#  'rodó': 60733,
#  'tres': 65845,
#  'protagonizaba': 57011,
#  ...}

# %%
results = {}
with tqdm(total=len(clasificadores) * 10) as pbar:
    for c in clasificadores:
        results[c] = { 'real': {}, 'cine_real': {}, 'predicted': {}, 'cine_predicted': {} }
        i = 0
        for train_index, test_index in folds:
            train_x = x_vect[train_index]
            train_y = train_corpus.polarity[train_index]
            test_x = x_vect[test_index]
            test_y = train_corpus.polarity[test_index]

            pipelines_train[c].fit(train_x, train_y)

            predicted = pipelines_train[c].predict(test_x)
            cine_pred = pipelines_train[c].predict(cine_vect)
            
            results[c]['real'][i] = test_y.values.tolist()
            results[c]['cine_real'][i] = cine.polarity.values.tolist()
            
            results[c]['predicted'][i] = predicted.tolist()
            results[c]['cine_predicted'][i] = cine_pred.tolist()
            i = i + 1

            pbar.update(1)
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/suampa/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-15-f1d6516e7e1b>", line 15, in <module>
#     cine_pred = pipelines_train[c].predict(cine_vect)
#   File "/home/suampa/.local/lib/python3.7/site-packages/sklearn/multiclass.py", line 302, in predict
#     pred = _predict_binary(e, X)
#   File "/home/suampa/.local/lib/python3.7/site-packages/sklearn/multiclass.py", line 95, in _predict_binary
#     score = np.ravel(estimator.decision_function(X))
#   File "/home/suampa/.local/lib/python3.7/site-packages/sklearn/linear_model/base.py", line 273, in decision_function
#     dense_output=True) + self.intercept_
#   File "/home/suampa/.local/lib/python3.7/site-packages/sklearn/utils/extmath.py", line 142, in safe_sparse_dot
#     return np.dot(a, b)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/suampa/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2033, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/suampa/.local/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/suampa/.local/lib/python3.7/site-packages/IPython/core/ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "/home/suampa/.local/lib/python3.7/site-packages/IPython/core/ultratb.py", line 347, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.7/inspect.py", line 742, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/usr/lib/python3.7/posixpath.py", line 395, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/usr/lib/python3.7/posixpath.py", line 429, in _joinrealpath
#     if not islink(newpath):
#   File "/usr/lib/python3.7/posixpath.py", line 171, in islink
#     st = os.lstat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %%
pd.DataFrame(results).to_pickle('../results/'+name+'/'+base_dir+'/results.pkl')
