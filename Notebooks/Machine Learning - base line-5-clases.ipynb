# %% [markdown]
# # Machine learning

# %% [markdown]
# ## Imports

# %%
import sys
import cufflinks
import pandas as pd
import numpy as np
from tqdm import tqdm
import warnings

warnings.filterwarnings('ignore')

sys.path.append('./..')
cufflinks.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from Corpus.Corpus import get_corpus, filter_binary_pn, filter_corpus_small
from auxiliar.VectorizerHelper import vectorizer, vectorizerIdf, preprocessor
from auxiliar import parameters
from auxiliar.HtmlParser import HtmlParser

# %%
from sklearn.calibration import CalibratedClassifierCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import roc_auc_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import roc_curve
from sklearn.model_selection import KFold
import copy

# %% [markdown]
# ## Config

# %%
polarity_dim = 5
clasificadores=['lr', 'ls', 'mb', 'rf']
idf =  False
target_names=['Neg', 'Pos']
kfolds = 10
base_dir = '2-clases' if polarity_dim == 2 else ('3-clases' if polarity_dim == 3 else '5-clases')
name = 'machine_learning/tweeter/base_line'

# %% [markdown]
# ## Get data

# %%
cine = HtmlParser(200, "http://www.muchocine.net/criticas_ultimas.php", 1)
data_corpus = get_corpus('general-corpus', 'general-corpus', 1, None)

if polarity_dim == 2:
    data_corpus = filter_binary_pn(data_corpus)
    cine = filter_binary_pn(cine.get_corpus())
elif polarity_dim == 3:
    data_corpus = filter_corpus_small(data_corpus)
    cine = filter_corpus_small(cine.get_corpus())
elif polarity_dim == 5:
    cine = cine.get_corpus()
cine = cine[:5000]
used_data = pd.DataFrame(data_corpus)
split = used_data.shape[0] * 0.7
data_corpus = None
# Out:
# #Intentando obtener datos del archivo csv...
# ./../Corpus/../data/general-corpus.csv
# #Datos recuperados!

# %% [markdown]
# ## Split data

# %%
used_data.reset_index().groupby('polarity').agg({'index': 'count'}).iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="6f33eb67-90c8-45db-9a70-0c5be019c726" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6f33eb67-90c8-45db-9a70-0c5be019c726")) {
#                     Plotly.newPlot(
#                         '6f33eb67-90c8-45db-9a70-0c5be019c726',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "index", "orientation": "v", "text": "", "type": "bar", "uid": "34b13bf3-66e3-45a9-931d-f0d549a2d288", "x": [1, 2, 3, 4, 5], "y": [825, 1161, 313, 1077, 1637]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": ""}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('6f33eb67-90c8-45db-9a70-0c5be019c726');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
train_corpus = used_data.loc[:split - 1 , :]
test_corpus = used_data.loc[split:, :]

# %% [markdown]
# ## Initialize ML

# %%
vect = vectorizerIdf if idf else vectorizer
ls = CalibratedClassifierCV(LinearSVC()) if polarity_dim == 2 else OneVsRestClassifier(CalibratedClassifierCV(LinearSVC()))
lr = LogisticRegression(solver='lbfgs') if polarity_dim == 2 else OneVsRestClassifier(LogisticRegression())
mb = MultinomialNB() if polarity_dim == 2 else OneVsRestClassifier(MultinomialNB())
rf = RandomForestClassifier() if polarity_dim == 2 else OneVsRestClassifier(RandomForestClassifier())

# %%
pipeline_ls = Pipeline([
    ('vect', copy.deepcopy(vect)),
    ('ls', ls)
])
pipeline_lr = Pipeline([
    ('vect', copy.deepcopy(vect)),
    ('lr', lr)
])
pipeline_mb = Pipeline([
    ('vect', copy.deepcopy(vect)),
    ('mb', mb)
])
pipeline_rf = Pipeline([
    ('vect', copy.deepcopy(vect)),
    ('rf', rf)
])

# %%
pipelines = {
    'ls': pipeline_ls,
    'lr': pipeline_lr,
    'mb': pipeline_mb,
    'rf': pipeline_rf
}
pipelines_train = {
    'ls': ls,
    'lr': lr,
    'mb': mb,
    'rf': rf
}

# %% [markdown]
# ## Train

# %%
folds = pd.read_pickle('../data/pkls/folds.pkl') # k-folds precargados
folds = folds.values

# %%
x_vect = vect.fit_transform(train_corpus.content, train_corpus.polarity).toarray()

# %%
cine_vect = vect.transform(cine.content).toarray()

# %%
vect.vocabulary_
# Out:
# {'marodriguezb': 10562,
#  'Gracias': 2338,
#  'MAR': 3011,
#  'Off': 3548,
#  'pensando': 11566,
#  'regalito': 12566,
#  'Sinde': 4396,
#  'va': 13912,
#  'SGAE': 4217,
#  'cuando': 7169,
#  'van': 13948,
#  'sus': 13391,
#  'corruptos': 7062,
#  'Intento': 2617,
#  'no': 11061,
#  'sacar': 12893,
#  'conclusiones': 6797,
#  'intento': 9732,
#  'Conozco': 1357,
#  'adicto': 5281,
#  'drama': 7883,
#  'Ja': 2695,
#  'ja': 9863,
#  'suena': 13334,
#  'algo': 5433,
#  'Toca': 4633,
#  'crackoviadeTV3': 7093,
#  'Grabación': 2336,
#  'dl': 7842,
#  'especial': 8382,
#  'Navideño': 3421,
#  'Mari': 3132,
#  'crismas': 7126,
#  'Buen': 1005,
#  'día': 7932,
#  'Lo': 2961,
#  'primero': 12035,
#  'mandar': 10478,
#  'abrazo': 5121,
#  'grande': 9126,
#  'Miguel': 3249,
#  'su': 13302,
#  'familia': 8669,
#  'libertadmontes': 10210,
#  'Hoy': 2492,
#  'podría': 11789,
#  'ser': 13057,
#  'grandeza': 9128,
#  'humana': 9399,
#  'Desde': 1599,
#  'escaño': 8322,
#  'Todo': 4639,
#  'listo': 10248,
#  'empezar': 8116,
#  'endiascomohoy': 8180,
#  'Congreso': 1349,
#  'http': 9389,
#  'co': 6613,
#  'Mu2yIgCb': 3327,
#  'Bdías': 900,
#  'EM': 1736,
#  'ira': 9802,
#  'puente': 12210,
#  'Si': 4370,
#  'vais': 13923,
#  'dejeis': 7430,
#  'llevar': 10296,
#  'tableta': 13429,
#  'PC': 3621,
#  'luego': 10352,
#  'Orbyt': 3579,
#  'De': 1554,
#  'momento': 10827,
#  'digo': 7727,
#  'más': 10940,
#  'Un': 4746,
#  'sistema': 13181,
#  'económico': 7972,
#  'recorta': 12489,
#  'dinero': 7737,
#  'prestaciones': 11993,
#  'sociales': 13212,
#  'refuerza': 12556,
#  'billón': 6067,
#  'medio': 10626,
#  'euros': 8510,
#  'bancos': 5980,
#  'necesita': 11011,
#  'repensarse': 12630,
#  'programascambiados': 12094,
#  'caca': 6213,
#  'ajuste': 5396,
#  'viernes': 14084,
#  'adri_22_22': 5310,
#  'TT': 4548,
#  'gracias': 9116,
#  'Carlos_Latre': 1152,
#  'GRACIAS': 2237,
#  'POR': 3634,
#  'EL': 1731,
#  'BUEN': 842,
#  'RATO': 3984,
#  'AMIGOS': 459,
#  'La': 2867,
#  'Universidad': 4756,
#  'confía': 6841,
#  'Calle': 1115,
#  'encarar': 8154,
#  'retos': 12729,
#  'ambiciosos': 5487,
#  '7dzPPija': 345,
#  'Me': 3188,
#  'ayudáis': 5927,
#  'indultoneiro': 9606,
#  'Por': 3833,
#  'si': 13108,
#  'Zapatero': 5038,
#  'quiere': 12315,
#  'sugerencia': 13346,
#  'último': 14386,
#  'consejo': 6887,
#  'ministros': 10762,
#  'Qao9uvsG': 3948,
#  'abcdesevilla': 5100,
#  'Recio': 4055,
#  'indicios': 9591,
#  'potentes': 11877,
#  'denunciar': 7475,
#  'responsables': 12707,
#  'ERE': 1750,
#  'wlDSs1yQ': 14219,
#  'Cuatro': 1456,
#  'altos': 5464,
#  'cargos': 6347,
#  'Empleo': 1858,
#  'denunciados': 7473,
#  'retirar': 12725,
#  'prejubilación': 11929,
#  'extrabajadores': 8615,
#  'LWHxzbuB': 2865,
#  'marcha': 10535,
#  'atrás': 5851,
#  'PP': 3635,
#  'posponer': 11867,
#  'devolución': 7668,
#  'CCAA': 1049,
#  'resbalón': 12666,
#  'Debería': 1559,
#  'asumir': 5813,
#  'fallo': 8655,
#  'mentir': 10661,
#  'diciendo': 7696,
#  'conoce': 6857,
#  'cuentas': 7188,
#  'Viernes': 4871,
#  'negro': 11032,
#  'Aumenta': 774,
#  'paro': 11420,
#  'Noviembre': 3483,
#  'disminuyen': 7805,
#  'afiliados': 5327,
#  'Seguridad': 4327,
#  'Social': 4410,
#  'triste': 13768,
#  'HerenciaPSOE': 2462,
#  'Accidente': 513,
#  'BUS': 847,
#  'VAO': 4779,
#  'km': 10057,
#  '12': 40,
#  'Motorista': 3319,
#  '30': 172,
#  'años': 5938,
#  'herido': 9308,
#  'menos': 10653,
#  'grave': 9136,
#  'SAMUR_PC': 4207,
#  'traslada': 13729,
#  'Hospital': 2489,
#  'Doce': 1678,
#  'Octubre': 3538,
#  'vía': 14189,
#  'EmergenciasMad': 1847,
#  'verdadera': 14009,
#  'seriedad': 13061,
#  'cómica': 7271,
#  'Niall': 3440,
#  'Binns': 945,
#  'retrata': 12738,
#  'Nicanor': 3441,
#  'Parra': 3715,
#  'premio': 11939,
#  'Cervantes': 1222,
#  'AxYtQ1by': 789,
#  'FF': 2054,
#  'deseas': 7568,
#  'desesperadamente': 7576,
#  'hacerme': 9238,
#  'haces': 9242,
#  'qué': 12341,
#  'dirán': 7766,
#  'Mis': 3275,
#  'xa': 14252,
#  'merpastor': 10688,
#  'volver': 14146,
#  'sonreír': 13256,
#  'GFVara': 2226,
#  'autentico': 5868,
#  '24horas_rne': 138,
#  'subidòn': 13313,
#  'CarmendelRiego': 1158,
#  'victoria': 14064,
#  'Agradezco': 548,
#  'trabajadores': 13672,
#  'sindicatos': 13169,
#  'desconvocatoria': 7552,
#  'huelga': 9393,
#  'aeropuerto': 5316,
#  'comprometido': 6762,
#  'mediar': 10617,
#  'sevillahoy': 13083,
#  'RdscubreNavidad': 4046,
#  'gran': 9125,
#  'iniciativa': 9654,
#  'momentos': 10829,
#  'Hay': 2445,
#  'recordar': 12485,
#  'importante': 9519,
#  'verdadero': 14011,
#  'Tercer': 4605,
#  'acto': 5235,
#  'Acuerdo': 520,
#  'Bancos': 864,
#  'centrales': 6458,
#  'dar': 7308,
#  'tiempo': 13573,
#  'Soy': 4445,
#  'consciente': 6873,
#  'estamos': 8433,
#  'pidiendo': 11676,
#  'esfuerzo': 8363,
#  'familias': 8672,
#  'castellanomanchegas': 6395,
#  'Eguiguren': 1803,
#  'Gobierno': 2320,
#  'negociado': 11027,
#  'ETA': 1771,
#  'Llevamos': 2955,
#  'dos': 7875,
#  'denunciándolo': 7480,
#  'gsDGB8NV': 9151,
#  'No': 3455,
#  'aprobado': 5685,
#  'ley': 10189,
#  'Mucho': 3337,
#  'ánimo': 14357,
#  'hoy': 9386,
#  'Armada': 726,
#  'Espero': 1946,
#  'podáis': 11791,
#  'brindarnos': 6138,
#  'quinta': 12324,
#  'Copa': 1390,
#  'Davis': 1549,
#  'MUCHA': 3041,
#  'SUERTE': 4235,
#  'WHsk2vv6': 4929,
#  'Blanco': 951,
#  'ministro': 10761,
#  'portavoz': 11848,
#  'funciones': 8925,
#  'desacredita': 7509,
#  'forma': 8830,
#  'rotunda': 12831,
#  'pte': 12183,
#  'PSE': 3649,
#  'Jesús': 2737,
#  'sabe': 12874,
#  'habla': 9210,
#  'cierto': 6551,
#  'vuelta': 14174,
#  'Pepemaras': 3761,
#  'PopularesCyL': 3832,
#  'anamariavielba': 5540,
#  'marmarev': 10560,
#  'ajimnezvelayos': 5393,
#  'jmoreta23': 9930,
#  'dllanosg': 7843,
#  'c_floriano': 6198,
#  'encanta': 8143,
#  'ver': 14003,
#  'aqui': 5714,
#  'TuDNIe': 4692,
#  'están': 8487,
#  'Valencia': 4805,
#  'España': 1933,
#  'recomiendo': 12475,
#  'exposición': 8599,
#  'hkjRpj9b': 9348,
#  'martacerame': 10567,
#  'maria_rey': 10541,
#  'Amigaaaaa': 640,
#  'holaaaa': 9356,
#  'guapaaaa': 9154,
#  'El': 1813,
#  'juez': 9987,
#  'imputa': 9541,
#  'directivos': 7757,
#  'Ciudad': 1269,
#  'Artes': 734,
#  'Ciencias': 1257,
#  'caso': 6390,
#  'Urdangarín': 4763,
#  'Parece': 3706,
#  'él': 14364,
#  'desempleo': 7571,
#  'EE': 1723,
#  'UU': 4736,
#  'baja': 5957,
#  'niveles': 11055,
#  'marzo': 10575,
#  '2009': 107,
#  '2RKKqQFG': 158,
#  'Granado': 2342,
#  'reconoce': 12478,
#  'da': 7290,
#  'datos': 7322,
#  'objetividad': 11146,
#  'estar': 8436,
#  'interinidad': 9745,
#  'antes': 5584,
#  'TelediarioInter': 4586,
#  '20': 101,
#  'Corazón': 1396,
#  'partío': 11442,
#  'Irlanda': 2647,
#  'enfrentarán': 8200,
#  'Eurocopa': 1991,
#  'Transparencia': 4669,
#  'Internacional': 2626,
#  'ocupa': 11182,
#  '31': 178,
#  'ranking': 12380,
#  '182': 73,
#  'pdetrás': 11505,
#  'Detrás': 1614,
#  'Chipre': 1246,
#  'Emiratos': 1849,
#  'Arabes': 712,
#  'Qatar': 3949,
#  'urge': 13880,
#  'transparencia': 13722,
#  'ya': 14286,
#  'RT': 4008,
#  'FanClubMASes': 2087,
#  'Éstas': 14344,
#  'Navidades': 3420,
#  'regala': 12561,
#  'solidaridad': 13232,
#  'positivegeneration': 11863,
#  'cont': 6921,
#  'BksU1DZv': 949,
#  'Crisis': 1439,
#  'identidad': 9452,
#  'LoidaLois': 2966,
#  'EvaORegan': 2004,
#  'Tú': 4712,
#  'española': 8379,
#  'encima': 8165,
#  'Teleton': 4590,
#  'hace': 9231,
#  'servicio': 13066,
#  'social': 13209,
#  'voy': 14166,
#  'apoyarlo': 5667,
#  'supuesto': 13387,
#  'karlagglez': 10045,
#  'Hs601N32': 2494,
#  'Cospedal': 1421,
#  'debería': 7350,
#  'pedir': 11512,
#  'perdón': 11602,
#  'utilizar': 13898,
#  'demagógica': 7452,
#  'rebaja': 12427,
#  'sueldo': 13328,
#  'funcionarios': 8924,
#  'ahora': 5373,
#  'aplica': 5652,
#  'pudor': 12200,
#  'Así': 756,
#  'gusta': 9173,
#  'Mónica': 3365,
#  'moniromaba': 10834,
#  'pedroj_ramirez': 11518,
#  'orden': 11265,
#  'jefe': 9902,
#  'Cualquiera': 1451,
#  'discutir': 7789,
#  'Ipad': 2636,
#  'orbyt': 11263,
#  'trabajo': 13680,
#  'Hace': 2417,
#  'cinco': 6555,
#  'meses': 10691,
#  'comunicó': 6774,
#  'escrito': 8339,
#  'interlocutor': 9748,
#  'preferente': 11910,
#  'IU': 2536,
#  'Ello': 1838,
#  'permitió': 11625,
#  'gobernar': 9084,
#  'Ahora': 562,
#  'pide': 11674,
#  'consensos': 6890,
#  'Bienvenidos': 939,
#  'Brigada': 991,
#  'anti': 5585,
#  'Vara': 4822,
#  'región': 12578,
#  'problema': 12060,
#  'deja': 7420,
#  'tirado': 13591,
#  'Monago': 3296,
#  'después': 7634,
#  'nombramiento': 11070,
#  'embudo': 8088,
#  'característica': 6337,
#  'derecha': 7497,
#  'Animo': 670,
#  'Eso': 1925,
#  'llevamos': 10294,
#  'maravilla': 10526,
#  'Deyra_love_BTR': 1617,
#  'AlejandroSanz': 593,
#  'QE': 3935,
#  '7DyF7Sus': 334,
#  'pone': 11817,
#  'punto': 12224,
#  'ganar': 8985,
#  'Sevilla': 4354,
#  'nuevo': 11115,
#  'talismán': 13436,
#  'Mañana': 3186,
#  '22h': 126,
#  'giraldatv': 9071,
#  'Ns8tOZqR': 3485,
#  'Bueno': 1012,
#  '5ª': 287,
#  'Felicidades': 2115,
#  'equipo': 8295,
#  'SSantiagosegura': 4232,
#  'angyfdz': 5561,
#  'flofdez': 8809,
#  'BORRADO': 834,
#  'ESTÁ': 1770,
#  'AMIGUETES': 460,
#  'UN': 4726,
#  'ABRUZO': 430,
#  'Para': 3702,
#  'nadaaaa': 10982,
#  'Sabeis': 4241,
#  'asi': 5795,
#  'veces': 13967,
#  'coincidimos': 6636,
#  'Os': 3589,
#  'mando': 10482,
#  'cariño': 6354,
#  'NWQIgoK5': 3397,
#  'Adiós': 528,
#  'casi': 6386,
#  'culminado': 7208,
#  'destape': 7639,
#  'Estado': 1956,
#  'Bienestar': 935,
#  'quedar': 12283,
#  'gastasen': 9015,
#  'risa': 12789,
#  'ilumina': 9482,
#  'almas': 5452,
#  'bañadas': 6014,
#  'tristeza': 13769,
#  'sonrisa': 13258,
#  'tibia': 13566,
#  'caricia': 6350,
#  'helada': 9292,
#  'soledad': 13226,
#  'Patrick': 3726,
#  'Detener': 1611,
#  'carrera': 6369,
#  'nuclear': 11108,
#  'Irán': 2650,
#  'prioridad': 12044,
#  'estratégica': 8459,
#  'máxima': 10942,
#  'Occidente': 3536,
#  'entiendo': 8253,
#  'Banco': 863,
#  'Central': 1215,
#  'Europeo': 1997,
#  'puede': 12206,
#  'prestar': 11997,
#  'Gobiernos': 2322,
#  'prestará': 11999,
#  'FMI': 2064,
#  'haga': 9253,
#  'Europa': 1993,
#  'Altos': 624,
#  'recelan': 12436,
#  'exhaustivo': 8546,
#  'traspaso': 13734,
#  'poderes': 11781,
#  'Aseguran': 741,
#  'convertido': 7006,
#  'fiscalización': 8794,
#  'zto5m1tw': 14330,
#  'Buenos': 1013,
#  'dias': 7686,
#  'buenos': 6161,
#  'siguen': 13135,
#  'siendo': 13120,
#  'Talking': 4561,
#  'Heads': 2453,
#  'jijijiji': 9918,
#  'sibe': 13113,
#  'mesa': 10690,
#  'jurado': 10009,
#  'Manolo': 3107,
#  'Escobar': 1913,
#  'haciendo': 9245,
#  'Lady': 2878,
#  'Marmalade': 3149,
#  'jojijii': 9937,
#  'Los': 2974,
#  'resultados': 12718,
#  'preliminares': 11932,
#  'Egipto': 1801,
#  'auguran': 5855,
#  'profundo': 12088,
#  'cambio': 6272,
#  'consecuencias': 6876,
#  'regionales': 12573,
#  'Falta': 2085,
#  'voto': 14164,
#  'rural': 12853,
#  'atenuará': 5835,
#  'Tranquilidad': 4668,
#  'carreteras': 6372,
#  'segundo': 13016,
#  'Puente': 3913,
#  'Constitución': 1370,
#  'NRk2uftQ': 3389,
#  'hospitalidad': 9380,
#  'IsabelaTortlini': 2654,
#  'Bienvenido': 938,
#  'DON': 1516,
#  'aarbeloa17': 5087,
#  'humilde': 9408,
#  'morada': 10853,
#  'En': 1863,
#  'Espolón': 1949,
#  'conmemorando': 6854,
#  'Día': 1709,
#  'Discapacidad': 1658,
#  '52olz4vl': 257,
#  'vándalos': 14187,
#  'arrancan': 5746,
#  'lápiz': 10369,
#  'Picasso': 3784,
#  'LfyNuArl': 2926,
#  'Esto': 1973,
#  'apoyar': 5666,
#  'verdad': 14008,
#  'DiputacionMLG': 1646,
#  'reducirá': 12529,
#  'impuestos': 9534,
#  '96': 386,
#  'pueblos': 12203,
#  'VIGtaT1k': 4788,
#  'agua': 5366,
#  'fria': 8887,
#  'despues': 7633,
#  'entrenamiento': 8268,
#  'mañana': 10604,
#  'comer': 6679,
#  'pasta': 11472,
#  'descanso': 7542,
#  'total': 13664,
#  'noche': 11064,
#  'muy': 10928,
#  'dificil': 7711,
#  'Que': 3955,
#  'corra': 7041,
#  'Dewars': 1615,
#  'DewarsSpain': 1616,
#  'jordievole': 9942,
#  'buenafuente': 6157,
#  'julia_otero': 10000,
#  'santi_millan': 12959,
#  'Jordi': 2752,
#  'Detenida': 1612,
#  'jefa': 9899,
#  'prestigiosa': 12001,
#  'ONG': 3517,
#  'rusa': 12854,
#  'control': 6979,
#  'electoral': 8045,
#  'leWFa7BO': 10131,
#  'Porque': 3834,
#  'programa': 12091,
#  'KimyTwitera': 2826,
#  'Buenafuente': 1008,
#  'dais': 7295,
#  'Mi': 3238,
#  'artículo': 5770,
#  'ESD': 1756,
#  'testarudez': 13556,
#  'consejero': 6883,
#  'Salud': 4263,
#  'riojano': 12787,
#  'Sanz': 4291,
#  'picota': 11671,
#  'M9poedN7': 3007,
#  'Sinceramente': 4394,
#  'estoy': 8455,
#  'observando': 11160,
#  'zona': 14327,
#  'recreo': 12498,
#  'psiquiátrica': 12177,
#  'Civil': 1273,
#  'patético': 11492,
#  'veo': 14002,
#  'vE8BhpJs': 13904,
#  'Con': 1332,
#  'Fina': 2136,
#  'mujer': 10905,
#  'amigos': 5505,
#  'reparto': 12629,
#  'Iceberg': 2549,
#  'nueva': 11112,
#  'película': 11549,
#  'Gabriel': 2253,
#  'Velázquez': 4833,
#  'Gabri': 2252,
#  'pasan': 11448,
#  'n2chJhTr': 10962,
#  'diario_sur': 7681,
#  'así': 5818,
#  'Patético': 3729,
#  'Son': 4426,
#  'personas': 11650,
#  'QDcW1amA': 3934,
#  'reservo': 12671,
#  'dónde': 7936,
#  'cómo': 7274,
#  'deposito': 7491,
#  'mis': 10777,
#  'ahorros': 5379,
#  'Sólo': 4505,
#  'obligado': 11153,
#  'trasparencia': 13733,
#  'pública': 12248,
#  'aunque': 5863,
#  'hay': 9280,
#  'experto': 8578,
#  'Bien': 934,
#  'siento': 13124,
#  'UEDila': 4720,
#  'bienvenida': 6060,
#  'ayer': 5915,
#  'Esperemos': 1944,
#  'aun': 5859,
#  'salga': 12917,
#  'adelante': 5274,
#  'YA': 4991,
#  'SOMOS': 4223,
#  '200': 102,
#  '000': 1,
#  'Preciosa': 3855,
#  'Perdóname': 3769,
#  'by': 6180,
#  'Pablo': 3663,
#  'Alborán': 582,
#  'from': 8892,
#  'SoundHound': 4444,
#  'u0CAbR3X': 13842,
#  'Ataque': 757,
#  'inyección': 9797,
#  'SQL': 4230,
#  'masivo': 10580,
#  'q4usPkRL': 12254,
#  'Mira': 3268,
#  'sblanco': 12978,
#  'árbol': 14361,
#  'gjBkxMpv': 9074,
#  'Nosesiaporto': 3476,
#  'Vamos': 4817,
#  'Chilenos': 1244,
#  'ultimo': 13855,
#  'banco': 5979,
#  'queda': 12279,
#  'lograremos': 10323,
#  'teleton': 13485,
#  'Ya': 5001,
#  'duermo': 7900,
#  'intentar': 9730,
#  'debe': 7342,
#  'difícil': 7717,
#  'Betolash': 928,
#  'Pau': 3730,
#  'cuánto': 7251,
#  '4x4': 247,
#  'jeep': 9898,
#  'terreno': 13546,
#  'maestra': 10419,
#  'MultiplicoComoPaulinaRubio': 3346,
#  'bueno': 6160,
#  'medios': 10630,
#  'comunicación': 6768,
#  'llenado': 10282,
#  'anuncios': 5618,
#  'oficiales': 11196,
#  'había': 9229,
#  'recortar': 12492,
#  'gasto': 9018,
#  'publico': 12193,
#  'Quien': 3966,
#  'denuncia': 7471,
#  'mil': 10733,
#  'pvcmalaga': 12240,
#  'mariviromero': 10558,
#  'concejala': 6783,
#  'favorita': 8699,
#  'JavierArenas_PP': 2720,
#  'critica': 7138,
#  'PepeGrinan': 3759,
#  'pida': 11672,
#  'MarianoRajoy': 3140,
#  'reunión': 12752,
#  'niega': 11045,
#  'alcaldes': 5410,
#  '5oMAB1Us': 281,
#  'Krugman': 2833,
#  'austeridad': 5867,
#  'está': 8484,
#  'matando': 10587,
#  'euro': 8501,
#  'CbRL2Rj8': 1205,
#  'el_pais': 8029,
#  'sgueina': 13104,
#  'quién': 12338,
#  'tapado': 13446,
#  'PSOE': 3651,
#  'respuesta': 12709,
#  'blog': 6079,
#  'aFKafvRL': 5078,
#  'leído': 10196,
#  'libros': 10215,
#  'Era': 1902,
#  'metáfora': 10702,
#  'rutenca': 12855,
#  'leido': 10160,
#  'licenciado': 10217,
#  'historia': 9342,
#  'contemporanea': 6939,
#  'master': 10583,
#  'integración': 9712,
#  'europea': 8507,
#  'Viva': 4885,
#  'ironía': 9814,
#  'cacmalaga': 6216,
#  'AFmBIYxK': 448,
#  'arte': 5762,
#  'cultura': 7216,
#  'pintura': 11712,
#  'museo': 10920,
#  'museums': 10921,
#  'Rajoy': 4026,
#  'vuelva': 14177,
#  'tener': 13518,
#  'relevancia': 12607,
#  'RGhPlkBR': 3997,
#  'Políticos': 3821,
#  'responden': 12699,
#  'ningún': 11052,
#  'país': 11501,
#  'mundo': 10913,
#  'homologable': 9363,
#  'nstro': 11106,
#  'tolera': 13623,
#  'semejante': 13028,
#  'práctica': 12169,
#  '7hoIl9HR': 348,
#  'antonlosada': 5605,
#  'Obviamente': 3532,
#  'contar': 6932,
#  'declaraciones': 7377,
#  'permitido': 11621,
#  'preguntas': 11927,
#  'podía': 11793,
#  'faltar': 8664,
#  'dominguito': 7860,
#  'tierra': 13578,
#  'final': 8771,
#  'cuñao': 7254,
#  'carlos_muela': 6358,
#  'l28AOIdR': 10063,
#  'Palmas': 3690,
#  'sevillanas': 13085,
#  'animar': 5565,
#  'Rafa': 4021,
#  'sevillaciudadtalisman': 13082,
#  'copadavis': 7029,
#  'Recién': 4057,
#  'llegada': 10269,
#  'Madrid': 3061,
#  'fin': 8770,
#  'casitaaa': 6389,
#  'frío': 8901,
#  'quiero': 12318,
#  'ni': 11042,
#  'imaginar': 9492,
#  'hará': 9271,
#  'sierra': 13125,
#  'Chico': 1240,
#  'Rita': 4135,
#  'europeo': 8508,
#  'mejor': 10633,
#  'cinta': 6560,
#  'animación': 5562,
#  'FF7giIse': 2055,
#  'Nadal': 3409,
#  'Toda': 4635,
#  'mano': 10502,
#  'Eres': 1903,
#  'vamos': 13943,
#  'Campeones': 1126,
#  'También': 4562,
#  'ELORRIO': 1734,
#  'Otro': 3598,
#  'passing': 11471,
#  'escalofriante': 8316,
#  'linea': 10240,
#  'tercero': 13537,
#  'ensaladera': 8224,
#  'cerca': 6467,
#  'VamosRafa': 4818,
#  'CopaDavis': 1391,
#  'ole': 11221,
#  'RafaelNadal': 4023,
#  'Dicen': 1628,
#  'Rey': 4118,
#  'Cartuja': 1173,
#  'DiA': 1619,
#  'TVE': 4552,
#  'tendría': 13515,
#  'sacarle': 12894,
#  'rato': 12396,
#  'hacer': 9234,
#  'patria': 11483,
#  'Sera': 4339,
#  'imparcialidad': 9502,
#  'BeaGarciaCHV': 901,
#  'Edurnity': 1799,
#  'apellido': 5637,
#  'camello': 6276,
#  'Tendré': 4595,
#  'reyes': 12765,
#  'magos': 10435,
#  'doy': 7878,
#  'carta': 6374,
#  'das': 7321,
#  'jajja': 9874,
#  'bss': 6150,
#  'marinitaMF': 10550,
#  'Ojo': 3556,
#  'Molas': 3292,
#  'tal': 13434,
#  'cual': 7166,
#  'broma': 6143,
#  'serio': 13062,
#  'Como': 1316,
#  'Mola': 3291,
#  'Jajjaja': 2708,
#  'Viaje': 4859,
#  'embajadas': 8082,
#  'catalanas': 6401,
#  'derroche': 7503,
#  'ABC': 424,
#  'sD2LV37R': 12869,
#  'abc_es': 5099,
#  'Este': 1966,
#  'set': 13078,
#  'ganando': 8984,
#  'público': 12250,
#  'argentino': 5729,
#  'Del': 1571,
#  'Potro': 3844,
#  'toalla': 13605,
#  'comenzaron': 6677,
#  'cantar': 6314,
#  'ganado': 8978,
#  'Ryankuletz': 4197,
#  'Creo': 1435,
#  'edurnity': 7999,
#  'puesto': 12217,
#  'responder': 12700,
#  'tweets': 13811,
#  'apellidos': 5638,
#  'iPhone': 9435,
#  'cosasquenuncaentenderas': 7073,
#  'jaajjajajja': 9865,
#  'Amonestado': 643,
#  'saluda': 12930,
#  'Qué': 3975,
#  'talla': 13437,
#  'campeón': 6288,
#  'saludando': 12932,
#  'Oe': 3541,
#  'oe': 11186,
#  'aquí': 5716,
#  'llegó': 10280,
#  'miembros': 10722,
#  'gente': 9048,
#  'dormirá': 7873,
#  'feliz': 8726,
#  'nadal': 10984,
#  'IMPRESIONANTE': 2522,
#  'Grandioso': 2345,
#  'cante': 6316,
#  'gritando': 9144,
#  'parar': 11392,
#  'corazón': 7036,
#  'sigo': 13133,
#  'partes': 11423,
#  'ESPAÑOL': 1760,
#  'partido': 11437,
#  'Putin': 3922,
#  'Medveded': 3202,
#  'Rusia': 4193,
#  'Unida': 4752,
#  'gana': 8977,
#  'comicios': 6690,
#  'sufre': 13344,
#  'fuerte': 8908,
#  'caía': 6419,
#  'Segundo': 4325,
#  'votado': 14158,
#  'Partido': 3717,
#  'Comunista': 1330,
#  'español': 8378,
#  'ejemplo': 8021,
#  'ilusión': 9487,
#  'superación': 13363,
#  'RbCb': 4043,
#  'Fantásticas': 2089,
#  'MarisolCovelo': 3144,
#  'parece': 11398,
#  'foto': 8852,
#  'elprimernaufragio': 8074,
#  'ZjCzROgC': 5051,
#  'CH3jjGX1': 1058,
#  'Fin': 2135,
#  'impunidad': 9540,
#  'Internet': 2629,
#  'j7WaLdS3': 9853,
#  'digno': 7726,
#  'ministra': 10758,
#  'italiana': 9840,
#  'Trabajo': 4667,
#  'llore': 10302,
#  'parecían': 11406,
#  'risas': 12790,
#  'Berlusconi': 915,
#  'Lágrimas': 3001,
#  'tecnócratas': 13477,
#  'Y7K9awBr': 4990,
#  'marianorajoy': 10547,
#  'ineptocracia': 9611,
#  'Semanaldigital': 4335,
#  'PPopular': 3642,
#  'PrsX6XAN': 3900,
#  'Portada': 3836,
#  'Público': 3930,
#  'Urdangarin': 4761,
#  'SA': 4205,
#  'Dentro': 1585,
#  'lista': 10246,
#  '103': 33,
#  'entidades': 8250,
#  'pagaron': 11339,
#  'Nóos': 3501,
#  'BP1Bfcl6': 836,
#  'días': 7934,
#  'queridos': 12303,
#  'twiteros': 13816,
#  'Venezuela': 4837,
#  'UdCRaDkY': 4738,
#  'Elisabeth': 1836,
#  ...}

# %%
results = {}
with tqdm(total=len(clasificadores) * 10) as pbar:
    for c in clasificadores:
        results[c] = { 'real': {}, 'cine_real': {}, 'predicted': {}, 'cine_predicted': {} }
        i = 0
        for train_index, test_index in folds:
            train_x = x_vect[train_index]
            train_y = train_corpus.polarity[train_index]
            test_x = x_vect[test_index]
            test_y = train_corpus.polarity[test_index]

            pipelines_train[c].fit(train_x, train_y)

            predicted = pipelines_train[c].predict(test_x)
            cine_pred = pipelines_train[c].predict(cine_vect)
            
            results[c]['real'][i] = test_y.values.tolist()
            results[c]['cine_real'][i] = cine.polarity.values.tolist()
            
            results[c]['predicted'][i] = predicted.tolist()
            results[c]['cine_predicted'][i] = cine_pred.tolist()
            i = i + 1

            pbar.update(1)
# Out:
# 100%|██████████| 40/40 [28:56<00:00, 101.22s/it]

# %%
pd.DataFrame(results).to_pickle('../results/'+name+'/'+base_dir+'/results.pkl')
